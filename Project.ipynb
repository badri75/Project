# %%
import numpy as np
import pandas as pd
import re

# %%
df =  pd.read_csv("Dataset/results.csv")
df.head()
# Out:
#          date home_team away_team  home_score  away_score tournament     city  \
# 0  1872-11-30  Scotland   England           0           0   Friendly  Glasgow
# 1  1873-03-08   England  Scotland           4           2   Friendly   London
# 2  1874-03-07  Scotland   England           2           1   Friendly  Glasgow
# 3  1875-03-06   England  Scotland           2           2   Friendly   London
# 4  1876-03-04  Scotland   England           3           0   Friendly  Glasgow
#
#     country  neutral
# 0  Scotland    False
# 1   England    False
# 2  Scotland    False
# 3   England    False
# 4  Scotland    False

# %%
df["date"] = pd.to_datetime(df["date"])
df.head()
# Out:
#         date home_team away_team  home_score  away_score tournament     city  \
# 0 1872-11-30  Scotland   England           0           0   Friendly  Glasgow
# 1 1873-03-08   England  Scotland           4           2   Friendly   London
# 2 1874-03-07  Scotland   England           2           1   Friendly  Glasgow
# 3 1875-03-06   England  Scotland           2           2   Friendly   London
# 4 1876-03-04  Scotland   England           3           0   Friendly  Glasgow
#
#     country  neutral
# 0  Scotland    False
# 1   England    False
# 2  Scotland    False
# 3   England    False
# 4  Scotland    False

# %%
df.isna().sum()
# Out:
# date          0
# home_team     0
# away_team     0
# home_score    0
# away_score    0
# tournament    0
# city          0
# country       0
# neutral       0
# dtype: int64

# %%
df.sort_values("date").tail()
# Out:
#             date  home_team    away_team  home_score  away_score  \
# 44347 2022-12-14   Malaysia     Maldives           3           0
# 44349 2022-12-14    Vietnam  Philippines           1           0
# 44351 2022-12-17  Singapore     Maldives           3           1
# 44350 2022-12-17    Croatia      Morocco           2           1
# 44352 2022-12-18  Argentina       France           3           3
#
#            tournament          city    country  neutral
# 44347        Friendly  Kuala Lumpur   Malaysia    False
# 44349        Friendly         Hanoi    Vietnam    False
# 44351        Friendly     Singapore  Singapore    False
# 44350  FIFA World Cup     Al Rayyan      Qatar     True
# 44352  FIFA World Cup        Lusail      Qatar     True

# %%
df = df[(df["date"] >= "2018-8-1")].reset_index(drop=True)
df = df[(df["date"] < "2022-11-20")].reset_index(drop=True)

# %%
df.home_team.value_counts()
# Out:
# United States               45
# Mexico                      42
# Qatar                       40
# Bahrain                     39
# Japan                       39
#                             ..
# Tonga                        1
# Bhutan                       1
# Alderney                     1
# Saint Helena                 1
# Northern Mariana Islands     1
# Name: home_team, Length: 247, dtype: int64

# %%
rank = pd.read_csv("Dataset/fifa_ranking-2022-10-06.csv")
rank.head()
# Out:
#    rank  country_full country_abrv  total_points  previous_points  \
# 0     1       Germany          GER          57.0              0.0
# 1    96         Syria          SYR          11.0              0.0
# 2    97  Burkina Faso          BFA          11.0              0.0
# 3    99        Latvia          LVA          10.0              0.0
# 4   100       Burundi          BDI          10.0              0.0
#
#    rank_change confederation   rank_date
# 0            0          UEFA  1992-12-31
# 1            0           AFC  1992-12-31
# 2            0           CAF  1992-12-31
# 3            0          UEFA  1992-12-31
# 4            0           CAF  1992-12-31

# %%
rank["rank_date"] = pd.to_datetime(rank["rank_date"])
rank = rank[(rank["rank_date"] >= "2018-8-1")].reset_index(drop=True)
rank = rank[(rank["rank_date"] < "2022-11-20")].reset_index(drop=True)

# %%
rank["country_full"] = rank["country_full"].str.replace("IR Iran", "Iran").str.replace("Korea Republic", "South Korea").str.replace("USA", "United States")

# %%
rank = rank.set_index(['rank_date']).groupby(['country_full'], group_keys=False).resample('D').first().fillna(method='ffill').reset_index()

# %%
df_wc_ranked = df.merge(rank[["country_full", "total_points", "previous_points", "rank", "rank_change", "rank_date"]], left_on=["date", "home_team"], right_on=["rank_date", "country_full"]).drop(["rank_date", "country_full"], axis=1)

# %%
df_wc_ranked = df_wc_ranked.merge(rank[["country_full", "total_points", "previous_points", "rank", "rank_change", "rank_date"]], left_on=["date", "away_team"], right_on=["rank_date", "country_full"], suffixes=("_home", "_away")).drop(["rank_date", "country_full"], axis=1)

# %%
df_wc_ranked[(df_wc_ranked.home_team == "Brazil") | (df_wc_ranked.away_team == "Brazil")].tail(10)
# Out:
#            date    home_team away_team  home_score  away_score  \
# 2530 2021-11-11       Brazil  Colombia           1           0
# 2631 2021-11-16    Argentina    Brazil           0           0
# 2739 2022-01-27      Ecuador    Brazil           1           1
# 2772 2022-02-01       Brazil  Paraguay           4           0
# 2813 2022-03-24       Brazil     Chile           4           0
# 2896 2022-03-29      Bolivia    Brazil           0           4
# 2988 2022-06-02  South Korea    Brazil           1           5
# 3056 2022-06-06        Japan    Brazil           0           1
# 3234 2022-09-23       Brazil     Ghana           3           0
# 3303 2022-09-27       Brazil   Tunisia           5           1
#
#                         tournament            city      country  neutral  \
# 2530  FIFA World Cup qualification       São Paulo       Brazil    False
# 2631  FIFA World Cup qualification        San Juan    Argentina    False
# 2739  FIFA World Cup qualification           Quito      Ecuador    False
# 2772  FIFA World Cup qualification  Belo Horizonte       Brazil    False
# 2813  FIFA World Cup qualification  Rio de Janeiro       Brazil    False
# 2896  FIFA World Cup qualification          La Paz      Bolivia    False
# 2988                      Friendly           Seoul  South Korea    False
# 3056                      Friendly           Tokyo        Japan    False
# 3234                      Friendly        Le Havre       France     True
# 3303                      Friendly           Paris       France     True
#
#       total_points_home  previous_points_home  rank_home  rank_change_home  \
# 2530            1820.36               1811.73        2.0               0.0
# 2631            1738.79               1725.31        6.0               0.0
# 2739            1448.27               1448.74       46.0               0.0
# 2772            1826.35               1826.35        2.0               0.0
# 2813            1823.42               1826.35        2.0               0.0
# 2896            1308.12               1324.21       76.0              -1.0
# 2988            1519.54               1522.85       29.0               0.0
# 3056            1553.44               1549.82       23.0               0.0
# 3234            1837.56               1837.56        1.0               0.0
# 3303            1837.56               1837.56        1.0               0.0
#
#       total_points_away  previous_points_away  rank_away  rank_change_away
# 2530            1618.76               1618.40       16.0               0.0
# 2631            1820.36               1811.73        2.0               0.0
# 2739            1826.35               1826.35        2.0               0.0
# 2772            1454.52               1454.52       43.0               0.0
# 2813            1543.16               1543.42       26.0               2.0
# 2896            1823.42               1826.35        2.0               0.0
# 2988            1832.69               1823.42        1.0              -1.0
# 3056            1832.69               1823.42        1.0              -1.0
# 3234            1393.47               1389.68       60.0               0.0
# 3303            1507.86               1507.86       30.0               0.0
